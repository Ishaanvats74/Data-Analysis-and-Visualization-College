# %%
import pandas as pd
import numpy as np

# %%
data = pd.Series(
    np.random.randn(9),
    index=[
        ['a','a','a','b','b','c','c','d','d'],
        [1,2,3,1,3,1,2,2,3]
    ]
)

print(data)
# Out:
# a  1   -0.095632
#    2    1.655961
#    3   -0.262909
# b  1    1.313269
#    3    0.253098
# c  1   -0.090967
#    2   -1.089645
# d  2   -2.082038
#    3    0.229561
# dtype: float64

# %%
print(data.index)
# Out:
# MultiIndex([('a', 1),
#             ('a', 2),
#             ('a', 3),
#             ('b', 1),
#             ('b', 3),
#             ('c', 1),
#             ('c', 2),
#             ('d', 2),
#             ('d', 3)],
#            )

# %%
print(data['b'])
print(data['b':'c'])
print(data.loc[['b','d']])
# Out:
# 1    1.313269
# 3    0.253098
# dtype: float64
# b  1    1.313269
#    3    0.253098
# c  1   -0.090967
#    2   -1.089645
# dtype: float64
# b  1    1.313269
#    3    0.253098
# d  2   -2.082038
#    3    0.229561
# dtype: float64

# %%
print(data.loc[:,2])
# Out:
# a    1.655961
# c   -1.089645
# d   -2.082038
# dtype: float64

# %%
print(data.unstack())
# Out:
#           1         2         3
# a -0.095632  1.655961 -0.262909
# b  1.313269       NaN  0.253098
# c -0.090967 -1.089645       NaN
# d       NaN -2.082038  0.229561

# %%
print(data.unstack().stack())
# Out:
# a  1   -0.095632
#    2    1.655961
#    3   -0.262909
# b  1    1.313269
#    2         NaN
#    3    0.253098
# c  1   -0.090967
#    2   -1.089645
#    3         NaN
# d  1         NaN
#    2   -2.082038
#    3    0.229561
# dtype: float64

# %%
frame = pd.DataFrame(
    np.arange(12).reshape((4,3)),
    index=[['a','a','b','b'], [1,2,1,2]],
    columns=[['Ohio','Ohio','Colorado'],
             ['Green','Red','Green']]
)

print(frame)
# Out:
#      Ohio     Colorado
#     Green Red    Green
# a 1     0   1        2
#   2     3   4        5
# b 1     6   7        8
#   2     9  10       11

# %%
frame.index.names = ['key1','key2']
frame.columns.names = ['state','color']

print(frame)
# Out:
# state      Ohio     Colorado
# color     Green Red    Green
# key1 key2
# a    1        0   1        2
#      2        3   4        5
# b    1        6   7        8
#      2        9  10       11

# %%
print(frame['Ohio'])
# Out:
# color      Green  Red
# key1 key2
# a    1         0    1
#      2         3    4
# b    1         6    7
#      2         9   10

# %%
col_index = pd.MultiIndex.from_arrays(
    [['Ohio','Ohio','Colorado'],
     ['Green','Red','Green']],
    names=['state','color']
)

print(col_index)
# Out:
# MultiIndex([(    'Ohio', 'Green'),
#             (    'Ohio',   'Red'),
#             ('Colorado', 'Green')],
#            names=['state', 'color'])

# %%
print(frame.swaplevel('key1','key2'))
# Out:
# state      Ohio     Colorado
# color     Green Red    Green
# key2 key1
# 1    a        0   1        2
# 2    a        3   4        5
# 1    b        6   7        8
# 2    b        9  10       11

# %%
print(frame.sort_index(level=1))
# Out:
# state      Ohio     Colorado
# color     Green Red    Green
# key1 key2
# a    1        0   1        2
# b    1        6   7        8
# a    2        3   4        5
# b    2        9  10       11

# %%
print(frame.swaplevel(0,1).sort_index(level=0))
# Out:
# state      Ohio     Colorado
# color     Green Red    Green
# key2 key1
# 1    a        0   1        2
#      b        6   7        8
# 2    a        3   4        5
#      b        9  10       11

# %%
print(frame.groupby(level='key1').sum())
# Out:
# state  Ohio     Colorado
# color Green Red    Green
# key1
# a         3   5        7
# b        15  17       19

# %%
print(frame.T.groupby(level='color').sum().T)
# Out:
# color      Green  Red
# key1 key2
# a    1         2    1
#      2         8    4
# b    1        14    7
#      2        20   10

# %%
frame = pd.DataFrame({'a': range(7), 'b': range(7, 0, -1),                     
'c': ['one', 'one', 'one', 'two', 'two','two', 'two'],
'd': [0, 1, 2, 0, 1, 2, 3]})
print(frame)
# Out:
#    a  b    c  d
# 0  0  7  one  0
# 1  1  6  one  1
# 2  2  5  one  2
# 3  3  4  two  0
# 4  4  3  two  1
# 5  5  2  two  2
# 6  6  1  two  3

# %%
frame.set_index(['c', 'd'], drop=False)
# Out:
#        a  b    c  d
# c   d
# one 0  0  7  one  0
#     1  1  6  one  1
#     2  2  5  one  2
# two 0  3  4  two  0
#     1  4  3  two  1
#     2  5  2  two  2
#     3  6  1  two  3

# %%
frame.reset_index()
# Out:
#    index  a  b    c  d
# 0      0  0  7  one  0
# 1      1  1  6  one  1
# 2      2  2  5  one  2
# 3      3  3  4  two  0
# 4      4  4  3  two  1
# 5      5  5  2  two  2
# 6      6  6  1  two  3

# %%
df1 = pd.DataFrame({'key': ['b', 'b', 'a', 'c', 'a', 'a', 'b'],'data1': range(7)})
df1
# Out:
#   key  data1
# 0   b      0
# 1   b      1
# 2   a      2
# 3   c      3
# 4   a      4
# 5   a      5
# 6   b      6

# %%
df2 = pd.DataFrame({'key': ['a', 'b', 'd'],'data2': range(3)})
df2
# Out:
#   key  data2
# 0   a      0
# 1   b      1
# 2   d      2

# %%
pd.merge(df1, df2)
# Out:
#   key  data1  data2
# 0   b      0      1
# 1   b      1      1
# 2   a      2      0
# 3   a      4      0
# 4   a      5      0
# 5   b      6      1

# %%
df3 = pd.DataFrame({'lkey': ['b', 'b', 'a', 'c', 'a', 'a', 'b'],'data1': range(7)})
df4 = pd.DataFrame({'rkey': ['a', 'b', 'd'],'data2': range(3)})

# %%
df3
# Out:
#   lkey  data1
# 0    b      0
# 1    b      1
# 2    a      2
# 3    c      3
# 4    a      4
# 5    a      5
# 6    b      6

# %%
df4
# Out:
#   rkey  data2
# 0    a      0
# 1    b      1
# 2    d      2

# %%
pd.merge(df3, df4, left_on='lkey', right_on='rkey')
# Out:
#   lkey  data1 rkey  data2
# 0    b      0    b      1
# 1    b      1    b      1
# 2    a      2    a      0
# 3    a      4    a      0
# 4    a      5    a      0
# 5    b      6    b      1

# %%
pd.merge(df1, df2, how='outer')
# Out:
#   key  data1  data2
# 0   a    2.0    0.0
# 1   a    4.0    0.0
# 2   a    5.0    0.0
# 3   b    0.0    1.0
# 4   b    1.0    1.0
# 5   b    6.0    1.0
# 6   c    3.0    NaN
# 7   d    NaN    2.0

# %%
pd.merge(df1, df2, on='key', how='left')
# Out:
#   key  data1  data2
# 0   b      0    1.0
# 1   b      1    1.0
# 2   a      2    0.0
# 3   c      3    NaN
# 4   a      4    0.0
# 5   a      5    0.0
# 6   b      6    1.0

# %%
pd.merge(df1, df2, how='inner')
# Out:
#   key  data1  data2
# 0   b      0      1
# 1   b      1      1
# 2   a      2      0
# 3   a      4      0
# 4   a      5      0
# 5   b      6      1
