# %%
import pandas as pd
import numpy as np

data = {
    'Name': ['Asha', 'Ravi', 'Karan', 'Meena', 'Arjun'],
    'Age': [23, 25, 22, 24, 26],
    'Marks': [85, 78, 92, 70, 88],
    'City': ['Delhi', 'Mumbai', 'Delhi', 'Chennai', 'Mumbai']
}

df = pd.DataFrame(data)
df.index = ['a','b','c','d','e']

df
# Out:
#     Name  Age  Marks     City
# a   Asha   23     85    Delhi
# b   Ravi   25     78   Mumbai
# c  Karan   22     92    Delhi
# d  Meena   24     70  Chennai
# e  Arjun   26     88   Mumbai

# %% [markdown]
# Q1. Select column Marks using bracket notation

# %%
df['Marks']
# Out:
# a    85
# b    78
# c    92
# d    70
# e    88
# Name: Marks, dtype: int64

# %% [markdown]
# Q2. Select columns Name and Age

# %%
df[['Name', 'Age']]
# Out:
#     Name  Age
# a   Asha   23
# b   Ravi   25
# c  Karan   22
# d  Meena   24
# e  Arjun   26

# %% [markdown]
# Q3. Select row with index label 'c'

# %%
df.loc['c']
# Out:
# Name     Karan
# Age         22
# Marks       92
# City     Delhi
# Name: c, dtype: object

# %% [markdown]
# Q4. Select rows from 'b' to 'd' using slicing

# %%
df.loc['b':'d']
# Out:
#     Name  Age  Marks     City
# b   Ravi   25     78   Mumbai
# c  Karan   22     92    Delhi
# d  Meena   24     70  Chennai

# %% [markdown]
# Q5. What is the difference between df[&#39;Age&#39;] and df[[&#39;Age&#39;]]?

# %%
df['Age']
# Out:
# a    23
# b    25
# c    22
# d    24
# e    26
# Name: Age, dtype: int64

# %%
df[['Age']]
# Out:
#    Age
# a   23
# b   25
# c   22
# d   24
# e   26

# %% [markdown]
# Q6. Select row 'd' and column 'Marks' using .loc

# %%
df.loc['d', 'Marks']
# Out:
# np.int64(70)

# %% [markdown]
# Q7. Select value at position (row 2, column 1) using .iloc

# %%
df.iloc[2, 1]
# Out:
# np.int64(22)

# %% [markdown]
# Q8. Select first 3 rows and first 2 columns using .iloc

# %%
df.iloc[0:3, 0:2]
# Out:
#     Name  Age
# a   Asha   23
# b   Ravi   25
# c  Karan   22

# %% [markdown]
# Q9. Select rows 'a' to 'c' and columns 'Name' and 'Marks'

# %%
df.loc['a':'c', ['Name', 'Marks']]
# Out:
#     Name  Marks
# a   Asha     85
# b   Ravi     78
# c  Karan     92

# %% [markdown]
# Q10. Difference between .loc slicing and .iloc slicing

# %%
df.loc['a':'c']
# Out:
#     Name  Age  Marks    City
# a   Asha   23     85   Delhi
# b   Ravi   25     78  Mumbai
# c  Karan   22     92   Delhi

# %%
df.iloc[0:3]
# Out:
#     Name  Age  Marks    City
# a   Asha   23     85   Delhi
# b   Ravi   25     78  Mumbai
# c  Karan   22     92   Delhi

# %% [markdown]
# Q11. Use .at and .iat to select single scalar value

# %%
df.at['b', 'Age']
# Out:
# np.int64(25)

# %%
df.iat[1, 1]
# Out:
# np.int64(25)

# %% [markdown]
# Q12. Select students with Marks > 80

# %%
df[df['Marks'] > 80]
# Out:
#     Name  Age  Marks    City
# a   Asha   23     85   Delhi
# c  Karan   22     92   Delhi
# e  Arjun   26     88  Mumbai

# %% [markdown]
# Q13. Select students from Mumbai

# %%
df[df['City'] == 'Mumbai']
# Out:
#     Name  Age  Marks    City
# b   Ravi   25     78  Mumbai
# e  Arjun   26     88  Mumbai

# %% [markdown]
# Q14. Select students whose Age is between 23 and 25

# %%
df[(df['Age'] >= 23) & (df['Age'] <= 25)]
# Out:
#     Name  Age  Marks     City
# a   Asha   23     85    Delhi
# b   Ravi   25     78   Mumbai
# d  Meena   24     70  Chennai

# %% [markdown]
# Q15. Students from Delhi AND Marks > 80

# %%
df[(df['City'] == 'Delhi') & (df['Marks'] > 80)]
# Out:
#     Name  Age  Marks   City
# a   Asha   23     85  Delhi
# c  Karan   22     92  Delhi

# %% [markdown]
# Q16. Replace Marks < 75 with NaN

# %%
df.loc[df['Marks'] < 75, 'Marks'] = np.nan
df
# Out:
#     Name  Age  Marks     City
# a   Asha   23   85.0    Delhi
# b   Ravi   25   78.0   Mumbai
# c  Karan   22   92.0    Delhi
# d  Meena   24    NaN  Chennai
# e  Arjun   26   88.0   Mumbai

# %% [markdown]
# Q17. Reindex to include new index 'f'

# %%
df = df.reindex(['a','b','c','d','e','f'])
df
# Out:
#     Name   Age  Marks     City
# a   Asha  23.0   85.0    Delhi
# b   Ravi  25.0   78.0   Mumbai
# c  Karan  22.0   92.0    Delhi
# d  Meena  24.0    NaN  Chennai
# e  Arjun  26.0   88.0   Mumbai
# f    NaN   NaN    NaN      NaN

# %% [markdown]
# Q18. Reorder index

# %%
df = df.reindex(['e','d','c','b','a'])
df
# Out:
#     Name   Age  Marks     City
# e  Arjun  26.0   88.0   Mumbai
# d  Meena  24.0    NaN  Chennai
# c  Karan  22.0   92.0    Delhi
# b   Ravi  25.0   78.0   Mumbai
# a   Asha  23.0   85.0    Delhi

# %% [markdown]
# Q19. Add new column Grade using reindex

# %%
df = df.reindex(columns=['Name','Age','Marks','City','Grade'])
df
# Out:
#     Name   Age  Marks     City  Grade
# e  Arjun  26.0   88.0   Mumbai    NaN
# d  Meena  24.0    NaN  Chennai    NaN
# c  Karan  22.0   92.0    Delhi    NaN
# b   Ravi  25.0   78.0   Mumbai    NaN
# a   Asha  23.0   85.0    Delhi    NaN

# %% [markdown]
# Q21. Use method='ffill' while reindexing

# %%
df1 = df.reindex(['a','b','c','d','e','f'])
print(df1)
print(df1.ffill())
# Out:
#     Name   Age  Marks     City  Grade
# a   Asha  23.0   85.0    Delhi    NaN
# b   Ravi  25.0   78.0   Mumbai    NaN
# c  Karan  22.0   92.0    Delhi    NaN
# d  Meena  24.0   88.0  Chennai    NaN
# e  Arjun  26.0   88.0   Mumbai    NaN
# f  Arjun  26.0   88.0   Mumbai    NaN

# %% [markdown]
# Q22. Drop row 'c'

# %%
df.drop('c')
# Out:
#     Name   Age  Marks     City  Grade
# e  Arjun  26.0   88.0   Mumbai    NaN
# d  Meena  24.0    NaN  Chennai    NaN
# b   Ravi  25.0   78.0   Mumbai    NaN
# a   Asha  23.0   85.0    Delhi    NaN

# %% [markdown]
# Q23. Drop column 'City'

# %%
df.drop('City', axis=1)
# Out:
#     Name   Age  Marks  Grade
# e  Arjun  26.0   88.0    NaN
# d  Meena  24.0    NaN    NaN
# c  Karan  22.0   92.0    NaN
# b   Ravi  25.0   78.0    NaN
# a   Asha  23.0   85.0    NaN

# %% [markdown]
# Q24. Drop rows 'a' and 'b' together

# %%
df.drop(['a','b'])
# Out:
#     Name   Age  Marks     City  Grade
# e  Arjun  26.0   88.0   Mumbai    NaN
# d  Meena  24.0    NaN  Chennai    NaN
# c  Karan  22.0   92.0    Delhi    NaN

# %% [markdown]
# Q25. Drop column 'Age' using axis=1

# %%
df.drop('Age', axis=1)
# Out:
#     Name  Marks     City  Grade
# e  Arjun   88.0   Mumbai    NaN
# d  Meena    NaN  Chennai    NaN
# c  Karan   92.0    Delhi    NaN
# b   Ravi   78.0   Mumbai    NaN
# a   Asha   85.0    Delhi    NaN

# %% [markdown]
# Q26. Difference between axis=0 and axis=1

# %%
df.drop('a', axis=0)
# Out:
#     Name   Age  Marks     City  Grade
# e  Arjun  26.0   88.0   Mumbai    NaN
# d  Meena  24.0    NaN  Chennai    NaN
# c  Karan  22.0   92.0    Delhi    NaN
# b   Ravi  25.0   78.0   Mumbai    NaN

# %%
df.drop('Age', axis=1)
# Out:
#     Name  Marks     City  Grade
# e  Arjun   88.0   Mumbai    NaN
# d  Meena    NaN  Chennai    NaN
# c  Karan   92.0    Delhi    NaN
# b   Ravi   78.0   Mumbai    NaN
# a   Asha   85.0    Delhi    NaN
